# %% [markdown]
# # Document Loading

# %%
# !pip install langchain

# %%
import os 
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_=load_dotenv(find_dotenv())

openai.api_key=os.environ["OPENAI_API_KEY"]

# %%
### Loading PDF

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader= PyPDFLoader(r"Interview_Cheat_Sheet.pdf")
pages=loader.load()

# %%
print(len(pages))
print(pages[0].page_content[:200])
# Out:
# 9
# Interviews
# Your personal guide to Software Engineering technical interviews.
# Table of Contents
# The Daily Byte
# Online Judges
# Data Structures
# Algorithms
# Greedy Algorithms
# Bitmasks
# Runtime Analysis
# Video

# %%
pages[0].metadata
# Out:
# {'producer': 'PDFCreator Online (www.pdfforge.org/online)',
#  'creator': 'PDFCreator Online (www.pdfforge.org/online)',
#  'creationdate': '2025-04-14T18:54:37+00:00',
#  'title': 'Merged with PDFCreator Online',
#  'moddate': '2025-04-14T18:54:37+00:00',
#  'source': 'Interview_Cheat_Sheet.pdf',
#  'total_pages': 9,
#  'page': 0,
#  'page_label': '1'}

# %%
from langchain_community.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.parsers import OpenAIWhisperParser
from langchain_community.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
url="https://www.youtube.com/watch?v=dQw4w9WgXcQ"
save_dir="docs/youtube/"
loader=GenericLoader(YoutubeAudioLoader([url],save_dir=save_dir),OpenAIWhisperParser())
docs=loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dQw4w9WgXcQ
# [youtube] dQw4w9WgXcQ: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] dQw4w9WgXcQ: Downloading android vr player API JSON
# [info] dQw4w9WgXcQ: Downloading 1 format(s): 140
# [download] docs\youtube\Rick Astley - Never Gonna Give You Up (Official Video) (4K Remaster).m4a has already been downloaded
# [download] 100% of    3.29MiB
# ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
# ---------------------------------------------------------------------------
# ...

# %%
docs[0].page_content[:200]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 docs[0].page_content[:200]
#
# NameError: name 'docs' is not defined

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader("https://langchain.com/docs/")
docs=loader.load()
docs[0].page_content[:200]
# Out:
# 'LangChain overview - Docs by LangChainSkip to main contentDocs by LangChain home pageOpen sourceSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationLangChain overviewDeep AgentsLangCha'

# %%
from langchain_community.document_loaders import NotionDirectoryLoader
loader=NotionDirectoryLoader("docs/notion/")
docs=loader.load()

# %%
len(docs)
# Out:
# 0
